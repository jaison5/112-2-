# %% [markdown]
# # 作業2：Json資料處理——哪國航司最賺錢、收入最多、前八名的領先差距最大來到多少？
# ## 2017每間航空公司收入營運狀況比較——依航司、國家、收入、營利、資產、市值、員工數
# ## 最終分析結果:
# ## 哪國收入最多的航司:美國
# ## 收入最多航空公司:美國航空
# ## 最大資本額差距:300億美金的差距
#
# 資料來源：國際航空運輸協會（International Air Transport Association)

# %%
import matplotlib.pyplot as plt

# 指定其他可用字體，例如 SimSun（中文字體）
plt.rcParams['font.family'] = 'Arial'
import pandas as pd
import matplotlib.pyplot as plt

# 讀取檔案
data = {
  "air": [
    {
      "RANK": 1,
      "airline": "dlta",
      "country": "USA",
      "income": 540.0,
      "Profit": 19.0,
      "assets": 731.0,
      "Market value": 258.8,
      "staff": "95,000"
    },
    {
      "RANK": 2,
      "airline": "American Airlines",
      "country": "USA",
      "income": 523.0,
      "Profit": 18.0,
      "assets": 668.0,
      "Market value": 89.7,
      "staff": "129,700"
    },
    {
      "RANK": 3,
      "airline": "United Airlines",
      "country": "USA",
      "income": 488.2,
      "Profit": 19.2,
      "assets": 704.2,
      "Market value": 135.3,
      "staff": "84,100"
    },
    {
      "RANK": 4,
      "airline": "Deutsche Lufthansa",
      "country": "GR",
      "income": 358.0,
      "Profit": 9.44,
      "assets": 488.0,
      "Market value": 106.3,
      "staff": "109,509"
    },
    {
      "RANK": 5,
      "airline": "Air France-KLM",
      "country": "FR/NL",
      "income": 294.0,
      "Profit": 9.73,
      "assets": 348.0,
      "Market value": 39.7,
      "staff": "11,000"
    },
    {
      "RANK": 6,
      "airline": "Southwest Airlines",
      "country": "USA",
      "income": 248.0,
      "Profit": 6.58,
      "assets": 355.0,
      "Market value": 172.1,
      "staff": "66,000"
    },
    {
      "RANK": 7,
      "airline": "International Consolidated Airlines Group",
      "country": "UK/SPN",
      "income": 243.0,
      "Profit": 4.74,
      "assets": 419.0,
      "Market value": 98.4,
      "staff": "66,044"
    },
    {
      "RANK": 8,
      "airline": "Turkish Airlines",
      "country": "TK",
      "income": 197.0,
      "Profit": 28.0,
      "assets": 320.0,
      "Market value": 106.8,
      "staff": "40,264"
    }
  ]
}

# 建立DataFrame
df = pd.DataFrame(data['air'])

# 將航空公司設定為索引
df.set_index('airline', inplace=True)

# 繪製長條圖
df['income'].plot(kind='bar', figsize=(10, 6))
plt.xlabel('airline')
plt.ylabel('income(M)')
plt.title('airline_income')
plt.xticks(rotation=45)
plt.show()
