# %%
import pandas as pd
import matplotlib.pyplot as plt

# 讀取CSV檔案
data = pd.read_csv('adult.csv')

# 提取Age和Income變數
age = data['Age']
income = data['Income']

# 繪製長條圖
plt.bar(age, income)
plt.xlabel('Age')
plt.ylabel('Income')
plt.title('Income by Age')
plt.show()
