# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('adult.csv')

income = data['Income']

plt.figure(figsize=(10, 6))

plt.hist(income, bins=10, edgecolor='k')

plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Income Distribution')

plt.show()
